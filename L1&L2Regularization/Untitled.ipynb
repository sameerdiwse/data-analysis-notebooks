# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')
X = df.drop(['target'], axis=1)
y = df[['target']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %% [markdown]
# ### Visualizing

# %%
model = LinearRegression()
model.fit(X_train, y_train)

train_mse = mean_squared_error(y_train, model.predict(X_train))
test_mse = mean_squared_error(y_test, model.predict(X_test))

plt.bar([0,1], [train_mse, test_mse], color=['red','green'], tick_label=['MSE Train','MSE Test']);

# %%
lasso_model = Lasso(alpha=1)

lasso_model.fit(X_train, y_train)

train_mse = mean_squared_error(y_train, lasso_model.predict(X_train))
test_mse = mean_squared_error(y_test, lasso_model.predict(X_test))

print(f'train_mse: {train_mse} and test_mse: {test_mse}')

plt.bar([0,1], [train_mse, test_mse], color=['red','green'], tick_label=['MSE Train','MSE Test']);
# Out:
# train_mse: 84.84424958690273 and test_mse: 166.48981408620267

# %%
ridge_model = Ridge(alpha=800)

ridge_model.fit(X_train, y_train)

train_mse = mean_squared_error(y_train, ridge_model.predict(X_train))
test_mse = mean_squared_error(y_test, ridge_model.predict(X_test))

print(f'train_mse: {train_mse} and test_mse: {test_mse}')

plt.bar([0,1], [train_mse, test_mse], color=['red','green'], tick_label=['MSE Train','MSE Test']);
# Out:
# train_mse: 8565.287265166584 and test_mse: 11022.237506335177
